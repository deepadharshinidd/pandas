# %%
import pandas as pd

# %%
d=pd.read_csv(r"C:\Users\91978\Downloads\csvreadd.csv")
print(d)
# Out:
#     name   lastname  roll no  java  php   c  cobal  total    avg  P GRADE  \
# 0  deepa  dharshini        1    78   87  89     76    330  82.50  p     A
# 1  priya  dharshini        2    99   72  90     56    317  79.25  p     B
# 2    ram      kumar        3    50   50  89     78    267  66.75  p     C
# 3  SELVA      KUMAR        4    45   67  45     89    246  61.50  p     C
#
#     vari  rank
# 0  32.50   NaN
# 1  29.25   NaN
# 2  16.75   NaN
# 3  11.50   NaN

# %%
d
# Out:
#     name   lastname  roll no  java  php   c  cobal  total    avg  P GRADE  \
# 0  deepa  dharshini        1    78   87  89     76    330  82.50  p     A
# 1  priya  dharshini        2    99   72  90     56    317  79.25  p     B
# 2    ram      kumar        3    50   50  89     78    267  66.75  p     C
# 3  SELVA      KUMAR        4    45   67  45     89    246  61.50  p     C
#
#     vari  rank
# 0  32.50   NaN
# 1  29.25   NaN
# 2  16.75   NaN
# 3  11.50   NaN

# %%
d.pop('lastname')
# Out:
# 0    dharshini
# 1    dharshini
# 2        kumar
# 3        KUMAR
# Name: lastname, dtype: object

# %%
d
# Out:
#     name  roll no  java  php   c  cobal  total    avg  P GRADE   vari  rank
# 0  deepa        1    78   87  89     76    330  82.50  p     A  32.50   NaN
# 1  priya        2    99   72  90     56    317  79.25  p     B  29.25   NaN
# 2    ram        3    50   50  89     78    267  66.75  p     C  16.75   NaN
# 3  SELVA        4    45   67  45     89    246  61.50  p     C  11.50   NaN

# %%
d.drop(['vari','rank'],axis=1)
# Out:
#     name  roll no  java  php   c  cobal  total    avg  P GRADE
# 0  deepa        1    78   87  89     76    330  82.50  p     A
# 1  priya        2    99   72  90     56    317  79.25  p     B
# 2    ram        3    50   50  89     78    267  66.75  p     C
# 3  SELVA        4    45   67  45     89    246  61.50  p     C

# %%
d
# Out:
#     name  roll no  java  php   c  cobal  total    avg  P GRADE   vari  rank
# 0  deepa        1    78   87  89     76    330  82.50  p     A  32.50   NaN
# 1  priya        2    99   72  90     56    317  79.25  p     B  29.25   NaN
# 2    ram        3    50   50  89     78    267  66.75  p     C  16.75   NaN
# 3  SELVA        4    45   67  45     89    246  61.50  p     C  11.50   NaN

# %%
d.drop([2])
# Out:
#     name  roll no  java  php   c  cobal  total    avg  P GRADE   vari  rank
# 0  deepa        1    78   87  89     76    330  82.50  p     A  32.50   NaN
# 1  priya        2    99   72  90     56    317  79.25  p     B  29.25   NaN
# 3  SELVA        4    45   67  45     89    246  61.50  p     C  11.50   NaN

# %%
d
# Out:
#     name  roll no  java  php   c  cobal  total    avg  P GRADE   vari  rank
# 0  deepa        1    78   87  89     76    330  82.50  p     A  32.50   NaN
# 1  priya        2    99   72  90     56    317  79.25  p     B  29.25   NaN
# 2    ram        3    50   50  89     78    267  66.75  p     C  16.75   NaN
# 3  SELVA        4    45   67  45     89    246  61.50  p     C  11.50   NaN

# %%
d.drop(['vari','rank'],axis=1,inplace=True)
print(d)
# Out:
#     name  roll no  java  php   c  cobal  total    avg  P GRADE
# 0  deepa        1    78   87  89     76    330  82.50  p     A
# 1  priya        2    99   72  90     56    317  79.25  p     B
# 2    ram        3    50   50  89     78    267  66.75  p     C
# 3  SELVA        4    45   67  45     89    246  61.50  p     C

# %%
j=pd.read_excel(r"C:\Users\91978\OneDrive\Desktop\excel\samex.xlsx")
print(j)
# Out:
#    pc_id  pc_desc  pf_id  discount_percentage
# 0     10  grocery      1                 0.06
# 1     11    diary      1                 0.05
# 2     12   fruits      1                 0.03
# 3     13      veg      1                 0.02

# %%
d
# Out:
#     name  roll no  java  php   c  cobal  total    avg  P GRADE
# 0  deepa        1    78   87  89     76    330  82.50  p     A
# 1  priya        2    99   72  90     56    317  79.25  p     B
# 2    ram        3    50   50  89     78    267  66.75  p     C
# 3  SELVA        4    45   67  45     89    246  61.50  p     C
